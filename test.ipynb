# %%
# read_log_times.py

def print_time_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            if '[TIME]' in line:
                print(line.strip())

# Example usage
print_time_lines('log.txt')
# Out:
# [TIME] Dataset initialization took 1.87 seconds.
# [TIME] Trainer initialization took 0.00 seconds.
# [TIME] Dataset initialization took 1.73 seconds.
# [TIME] Trainer initialization took 0.00 seconds.
# [TIME] __getitem__ index 103869 took 0.0022 sec
# [TIME] __getitem__ index 97211 took 0.0027 sec
# [TIME] __getitem__ index 3598 took 0.0032 sec
# [TIME] __getitem__ index 125208 took 0.0005 sec
# [TIME] __getitem__ index 28443 took 0.0029 sec
# [TIME] __getitem__ index 65950 took 0.0011 sec
# [TIME] __getitem__ index 930 took 0.0008 sec
# [TIME] __getitem__ index 120216 took 0.0006 sec
# [TIME] __getitem__ index 28405 took 0.0004 sec
# [TIME] __getitem__ index 10636 took 0.0008 sec
# [TIME] __getitem__ index 134119 took 0.0013 sec
# [TIME] __getitem__ index 145285 took 0.0004 sec[TIME] __getitem__ index 19337 took 0.0003 sec
# [TIME] __getitem__ index 76029 took 0.0003 sec
# [TIME] __getitem__ index 147107 took 0.0006 sec
# ...
